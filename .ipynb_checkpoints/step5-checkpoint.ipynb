# %%
# %run feature_engineering.py
# Out:
# Duplicates in original data: 4896
# Removed 4896 duplicate rows based on ['season', 'GW', 'element']
# Duplicates after feature engineering: 0
# Feature engineered data saved to data/feature_engineered_data.csv
#          name position     team   xP  assists_x  bonus  bps  clean_sheets  \
# 0  Bernd_Leno       GK  Arsenal  3.6          0      0   11             0
# 1  Bernd_Leno       GK  Arsenal  1.5          0      0   17             0
# 2  Bernd_Leno       GK  Arsenal  0.8          0      0   20             0
# 3  Bernd_Leno       GK  Arsenal  2.0          0      0    0             0
# 4  Bernd_Leno       GK  Arsenal  1.8          0      0    0             0
#
#    creativity  element  ...  player_points_season_avg  form_trend  \
# 0         0.0        1  ...                  0.000000    0.000000
# 1         0.0        1  ...                  1.000000    0.020824
# 2         0.0        1  ...                  1.500000   -0.188156
# ...

# %%
# %run fpl_model_training.py
# Out:
# Columns in df: ['name', 'position', 'team', 'xP', 'assists_x', 'bonus', 'bps', 'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded', 'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes', 'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards', 'round', 'saves', 'selected', 'team_a_score', 'team_h_score', 'threat', 'total_points', 'transfers_balance', 'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards', 'GW', 'xG', 'xA', 'goals', 'assists_y', 'shots', 'key_passes', 'season', 'expected_assists', 'expected_goal_involvements', 'expected_goals', 'expected_goals_conceded', 'starts', 'team_points', 'team_goals_scored_last_5', 'team_goals_conceded_last_5', 'team_win_streak', 'team_form_momentum', 'opponent_goals_conceded_last_5', 'player_points_ewma', 'goals_scored_last_3', 'assists_last_3', 'minutes_last_3', 'bps_last_3', 'fixture_difficulty', 'is_home', 'clean_sheet_prob', 'goal_involvement_rate', 'form_vs_opponent', 
# ...

# %%
pip install lightgbm catboost
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------------------------------------ --- 1.3/1.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.5/101.7 MB 764.3 kB/s eta 0:02:13
#     --------------------------------------- 2.1/101.7 MB 3.1 MB/s eta 0:00:33
#    - -------------------------------------- 3.9/101.7 MB 4.7 MB/s eta 0:00:21
#    -- ------------------------------------- 6.0/101.7 MB 5.8 MB/s eta 0:00:17
#    --- ------------------------------------ 7.9/101.7 MB 6.2 MB/s eta 0:00:16
#    --- ------------------------------------ 10.0/101.7 MB 6.7 MB/s eta 0:00:14
#    ---- ----------------------------------- 11.8/101.7 MB 7.0 MB/s eta 0:00:13
# ...
